# %%
# %pylab inline
import csv
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# importando datos
ifile = open('autovectores_pobreza.csv',"rb")
reader = csv.reader(ifile)
autovectores = []
for row in reader:
    autovectores.append(row)
ifile.close()
ifile = open('autovalores_pobreza.csv',"rb")
reader = csv.reader(ifile)
autovalores = []
for row in reader:
    autovalores.append(row)
ifile.close()
ifile = open('datos_pobreza.csv',"rb")
reader = csv.reader(ifile)
data = []
for row in reader:
    data.append(row)
ifile.close()
ifile = open('ciudades_pobreza.csv',"rb")
reader = csv.reader(ifile)
ciud = []
for row in reader:
    ciud.append(row)
ifile.close()
ciudades = []
for i in range(len(ciud)):
    x= ""
    for j in range(len(ciud[i])):
        x = x + ciud[i][j]
    ciudades.append(x)

# %%
#obteniendo coeficientes
diagonal = zeros([len(autovalores[0]),len(autovalores[0])])
for i in range(len(autovalores[0])):
    diagonal[i][i] = float(autovalores[0][i])

Matriz = []
columna = []
for i in range(len(data)):
    columna = []
    for j in range(len(diagonal)):
        columna.append(float(data[i][j]))
    Matriz.append(columna) 

inversa = []
for i in range(len(diagonal)):
    columna = []
    for j in range(len(diagonal)):
        columna.append(float(autovectores[i][j]))
    inversa.append(columna)
inversa = inv(inversa)

coef = []
for i in Matriz:
    columna = []
    array(inversa)
    array(i)
    r = dot(inversa,i)
    for j in range(len(Matriz[0])):
        columna.append(r[j])
    coef.append(columna)
print coef
# Out:
# [[-0.29142436123143417, -0.26637468480333903, -0.12074588671498609], [-0.85256854246136982, -0.14154489043058582, -0.1518346094924839], [-0.39618665540818271, -0.28364651177975686, -0.17762117690198059], [-0.4942869496060317, -0.26461023520201998, -0.17987487947549075], [-0.56706560353105051, -0.27019484864365823, -0.17189422293070877], [-0.73127651165607721, -0.31269550550559017, -0.079671065182009532], [-0.56219801629420429, -0.29573504230538034, -0.078771583456671707], [-0.61066633425745931, -0.35650710487755088, -0.089137667158703998], [-1.1229667974572206, -0.20960933312192681, -0.13147546516575176], [-1.0275045790240009, -0.28578607655528299, -0.20231080263557327], [-0.47569223417151779, -0.38179011997268808, -0.048324165817730719], [-0.70736652936496014, -0.30318202685244561, -0.012704564839412402], [-0.45769073454993919, -0.46976380639243992, -0.078441050145408975], [-0.48414134479498283, -0.64401594488179548, -0.047990101528251339], [-0.54628559720279224, -0.36981740249628042, -0.14345109471972017], [-0.32811309183366127, -0.67169526644714472, -0.038885089862944644], [-0.36517345073906371, -0.35730348947186708, -0.20582139745872985], [-0.74101362480668309, -0.17795817263906649, -0.23872470030720133], [-0.27380077190770663, -0.28025360130136945, -0.17295111348205228], [-0.66657556832566045, -0.2943816411549558, 0.0074927772593867958], [-0.94241693078075817, -0.19686462648687969, -0.036971521469119112], [-0.59606725679822181, -0.29139149109884616, -0.076255668055897841], [-1.756024449670339, 0.18374015650911912, -0.14514324939792872], [-1.1309732107837713, -0.28682399890587496, -0.098285443426506691], [-0.86781413261062768, -0.48632001011421355, -0.086544668296620442], [-1.0391825399716959, -0.11181017915823999, -0.099428504732694128], [-0.22103503798603993, -0.24259386405368924, -0.1146976044743209], [-0.92517464747318967, -0.31331734770978048, -0.041262333783994853], [-0.56974413540693436, -0.49179302501095346, -0.13514762610770553], [-0.24524086484123089, -0.43741037236684582, -0.094146365969673129], [-0.40192730860551013, -0.33496327611920473, -0.10722874764907228], [-0.56941573384350352, -0.40962767946818152, -0.1442915488023625], [-0.40114695280327978, -0.28942531931809823, -0.17964615751576199], [0.035962959396310668, -0.57230781084679017, -0.15033286100664511], [-0.51088732114108903, -0.49900773024805156, -0.10558326676625607], [-0.41951462943009521, -0.49178929742895572, -0.14368208974235769], [-0.19645775666902571, -0.43037487446908673, -0.13788342850859422], [-0.52626154066854758, -0.42674692462814001, -0.10009712977545188], [-0.48674859505683116, -0.27296752936404534, -0.12359633990320193], [-0.87782246863428792, -0.22130391235769054, 0.0054943227180590526], [-0.14384463378811474, -0.32900967338654025, -0.15061351491299391], [-1.3839414446258709, -0.20155156611064529, -0.013319181236995714], [-0.53380827260676933, -0.20316746439903008, -0.16988332044493043], [-0.30942187012119582, -0.5559344592499903, -0.069683843333505191], [-0.56840789609080855, -0.4637296576812785, -0.0882859395787782], [-0.49608059440030944, -0.19262786950080951, -0.23526611902622752], [-0.093576014771177482, -0.23388670559102054, -0.10098798750687669], [-0.33831402335546029, -0.44554734171335075, -0.07616749200077344], [-0.715140763642101, -0.34986899437389252, -0.095861683462024588], [-0.43256237332259873, -0.39288708219321711, -0.16116304066070997], [-0.10026276146657111, -0.45218894586453195, -0.15286708878275362], [-0.40839160303422589, -0.47556012113670837, -0.15940259299493525], [-0.67674934176204504, -0.30729029054323037, -0.28052143884363168], [-0.60076606060657689, -0.47989083158831147, -0.14302026386523028], [-0.35015086908109827, -0.30341777110398682, -0.16253770602826167], [-0.26234849916669312, -0.34115042045749028, -0.20599505951237015], [-0.39537401284101847, -0.44960618028418964, -0.088571411375528958], [-0.25483810097883841, -0.49896075101926529, -0.002654057796574294], [-0.21254340448882131, -0.21164904492499104, -0.13 ...

# %%
#definiendo centro


k = 2
def centro_aleatorio(k):
    global centro
    centro = [[]for i in xrange(k)]
    for i in range(len(centro)):
        centro[i] = ones(len(coef[0]))*random.random(len(coef[0]))*max(coef[0])

centro_aleatorio(k)

# %%
#método que da el centro más cercano 
def distancia(a,k):
    
    global centro
    d = zeros(k)
    for i in range(len(d)):
        for j in range(len(a)):
            d[i] = d[i] + (a[j]-centro[i][j])**2
    
    num = 0
    menor = max(d)*2
    for i in range(len(d)):
        for j in range(len(d)):
            if(d[i]<d[j] and d[i]<menor):
                menor = d[i]
                num = i + 1

    return num

# %%
# clasificando puntos
V = [[] for x in xrange(k)]
def reiniciar():
    global V
    global k
    V = [[] for x in xrange(k)]

    
def clasificar():
    global it
    global V
    global clas
    global coef
    global k        
    clas = np.zeros(len(coef))
   
    for i in range(len(coef)):
        coord = coef[i]
        clas[i] = distancia(coord,k)
    for i in range(len(coef)):
        for j in range(len(V)):
           
            if clas[i] == float(j + 1):
                V[j].append(coef[i])
    for i in range(len(V)):
        if (it <= 100):
            if(len(V[i])<=0):
                it = it + 1
                centro_aleatorio(k)
                reiniciar()
                clasificar()
    
            
def empezar(k):
    global clas
    clas = np.zeros(len(coef))
    for i in range(len(coef)):
            clas[i] = (i % k) + 1
    for i in range(len(coef)):
        for j in range(len(V)):
           
            if clas[i] == float(j + 1):
                V[j].append(coef[i])
    global Vtemp
    Vtemp = V*2

# %%
#nuevo centro

def nuevo_centro():
    global V
    global centro
    global k

    for i in range(len(V)):
        
        mean = zeros(len(V[0][0]))
        for j in range(len(V[i])):
        
            
            
            if len(V[i]) > 0:
                mean = mean + array(V[i][j])
            else:
                centro_aleatorio(k)
                reiniciar()
                nuevo_centro()
        
        mean = mean/float(len(V[i]))
        centro[i] = mean

# %%
#clasificar ciudades
def clasificar_ciudades():
    global clas
    global ciudades
    global clas_ciudades
    global k
    clas_ciudades = [[] for x in xrange(k)]
    for i in range(len(clas)):
        for j in range(k):
            if (clas[i] == (j + 1)):
                clas_ciudades[j].append(ciudades[i])

# %%
# K_cluster

def comparar():
    global V
    global Vtemp
    comp = (Vtemp == V)
    return comp
def k_cluster(n):
    global k
    k = n
    global Vtemp
    global centro
    global V
    global coef
    global it
    it = 0
    if (n>len(coef)):
        print "Se piden más Clusters que puntos en el espacio: " + str(k)
        print ""
        return 0
    reiniciar()
    empezar(k)
    centro_aleatorio(k)
    nuevo_centro()
    centrotemp = centro*2
    d = True
    while(d):
        if(it<=100):
            reiniciar()
            clasificar()
            if(it <= 100):
                nuevo_centro()
                valor = comparar()
                d = valor
                Vtemp = V
            else:
                d =False
                print "No se encontraron los Clusters pedidos: " + str(k)
                print ""
    if(it <= 100):
        print "Se encontraron los Clusters solicitados: " + str(k)
        print ""
        print "Los centros pedidos son:"
        print centro
        print ""
        puntos = zeros(len(V))
        for i in range(len(V)):
            puntos[i] = len(V[i])
        print "ÉL numero de puntos por Cluster es:" 
        print puntos
        print ""
    clasificar_ciudades()
    print clas_ciudades

# %%
# ejecutar
for i in range(4):
    k_cluster(int(i+2))
# Out:
# Se encontraron los Clusters solicitados: 2
#
# Los centros pedidos son:
# [array([-0.26953772, -0.50884077, -0.1054549 ]), array([-0.98279157, -0.2737295 , -0.16185117])]
#
# ÉL numero de puntos por Cluster es:
# [ 661.  452.]
#
# [['Medell\xc3\xadn', 'Abriaqui', 'Alejandr\xc3\xada', 'Amag\xc3\xa1', 'Andes', 'Santaf\xc3\xa9 de Antioquia', 'Apartad\xc3\xb3', 'Arboletes', 'Argelia*', 'Armenia', 'Barbosa', 'Bello', 'Ciudad Bol\xc3\xadvar', 'Caldas', 'Caracol\xc3\xad', 'Caramanta', 'El Carmen De Viboral', 'Carolina del Principe', 'Caucasia', 'Chigorod\xc3\xb3', 'Cisneros', 'Cocorn\xc3\xa1', 'Concepci\xc3\xb3n', 'Copacabana', 'Don Mat\xc3\xadas', 'Ebejic\xc3\xb3', 'Entrerrios', 'Envigado', 'Fredonia', 'Giraldo', 'Girardota', 'G\xc3\xb3mez Plata', 'Guarne', 'Guatape', 'Heliconia', 'Hispania', 'Itagui', 'Jard\xc3\xadn', 'Jeric\xc3\xb3', 'La Ceja', 'La Estrella', 'La Pintada', 'La Uni\xc3\xb3n', 'Maceo', 'Marinilla', 'Olaya', 'Pe\xc3\xb1ol', 'Pueblorrico', 'Puerto Berrio', 'Puerto Nare (La Magdalena)', 'Retiro', 'Rionegro', 'Sabaneta',
', 'Sutamarchan', 'Sutatenza', 'Tasco', 'Tenza', 'Tiban\xc3\xa1', 'Tibasosa', 'Tinjaca', 'Tipacoque', 'Toca', 'T\xc3\xb3paga', 'Tunungua', 'Turmequ\xc3\xa9', 'Tuta', 'Tutaz\xc3\xa1', 'Umbita', 'Ventaquemada', 'Viracach\xc3\xa1', 'Zetaquira', 'Manizales', 'Anserma', 'Aranzazu', 'Belalcazar', 'Chinchina', 'La Dorada', 'La Merced', 'Manzanares', 'Marmato', 'Marquetalia', 'Marulanda', 'Neira', 'Norcasia', 'P\xc3\xa1cora', 'Palestina', 'Risaralda', 'Salamina', 'San Jos\xc3\xa9', 'Sup\xc3\xada', 'Victoria', 'Villamar\xc3\xada', 'Viterbo', 'Florencia', 'Popay\xc3\xa1n', 'L\xc3\xb3pez de Micay', 'Miranda', 'Padilla', 'Pat\xc3\xada', 'Puerto Tejada', 'Santander de Quilichao', 'Timbio', 'Villa Rica', 'Aguachica', 'Agust\xc3\xadn Codazzi', 'Chiriguana', 'Curumani', 'Gamarra', 'La Gloria', 'La Jagua de Ibirico', 'Manaure Balcon del Cesar', 'Pailitas', 'Pelaya', 'R\xc3\xado De Oro', 'Robles - La Paz', 'San Diego', 'Tama ...
# Se encontraron los Clusters solicitados: 3
# Los centros pedidos son:
# [array([-0.52530538, -0.27035585, -0.13808872]), array([-0.25445938, -0.54666027, -0.10195049]), array([-1.03357665, -0.24227545, -0.16654271])]
#
# ÉL numero de puntos por Cluster es:
# [  93.  617.  403.]
#
# [['Alejandr\xc3\xada', 'Amag\xc3\xa1', 'Andes', 'Argelia*', 'Ciudad Bol\xc3\xadvar', 'Carepa', 'Concepci\xc3\xb3n', 'Don Mat\xc3\xadas', 'Entrerrios', 'Jard\xc3\xadn', 'La Ceja', 'La Uni\xc3\xb3n', 'Pe\xc3\xb1ol', 'Puerto Berrio', 'San Andr\xc3\xa9s de Cuerquia', 'San Jos\xc3\xa9 de la Monta\xc3\xb1a', 'San Roque', 'San Vicente', 'Santa B\xc3\xa1rbara', 'Santa Rosa de Osos', 'El Santuario', 'Toledo', 'Vegach\xc3\xad', 'Yolomb\xc3\xb3', 'Soledad', 'P\xc3\xa1ez', 'San Luis De Gaceno', 'Aguadas', 'Anserma', 'Aranzazu', 'Belalcazar', 'Marmato', 'Marquetalia', 'Marulanda', 'Neira', 'Riosucio', 'Caloto', 'Arbelaez', 'Cucunub\xc3\xa1', 'El Rosal', 'Gachancipa', 'Granada', 'Gutierrez', 'La Calera', 'Nemoc\xc3\xb3n', 'Pasca', 'San Bernardo', 'Sesquil\xc3\xa9', 'Soacha', 'Rivera', 'Acacias', 'Lejan\xc3\xadas', 'El Tambo', 'Imues', 'Ipiales', 'Pupiales', 'San Pablo', 'C\xc3\xbacuta', 'Cacota', 'Labateca', 'Mutiscua', 'Pamplonita', 'Santiago', 'Toledo', 'C\xc3\xb3rdoba', 'G\xc3\xa9nova', 'Quimbaya', 'Apia', 'Belen de Umbria', 'Guatica', 'La Celia', 'Marsella', 'Barichara', 'Cimitarra', 'Confines', 'Curiti', 'Lebrija', 'Ocamontes', 'San Vicente De Chucur\
3\xa1meza', 'Garagoa', 'Guacamayas', 'Guateque', 'Guayat\xc3\xa1', 'Iza', 'Jenesano', 'La Capilla', 'La Victoria', 'La Uvita', 'Villa De Leyva', 'Macanal', 'Miraflores', 'Mongua', 'Mongu\xc3\xad', 'Moniquir\xc3\xa1', 'Muzo', 'Nobsa', 'Nuevo Col\xc3\xb3n', 'Oicat\xc3\xa1', 'Pachavita', 'Paipa', 'Pajarito', 'Panqueba', 'Paz De R\xc3\xado', 'Pesca', 'Quipama', 'Ramiriqu\xc3\xad', 'R\xc3\xa1quira', 'Rond\xc3\xb3n', 'Saboya', 'San Eduardo', 'San Jos\xc3\xa9 De Pare', 'San Mateo', 'San Miguel de Sema', 'Santana', 'Santa Mar\xc3\xada', 'Santa Rosa De Viterbo', 'Santa Sof ...
# Se encontraron los Clusters solicitados: 4
# Los centros pedidos son:
# [array([-0.30507244, -0.58539228, -0.02386634]), array([-1.01555972, -0.23091446, -0.16829563]), array([-0.27080341, -0.43000694, -0.12183158]), array([-0.31878436, -0.73382734, -0.07302921])]
#
# ÉL numero de puntos por Cluster es:
# [  24.  417.  472.  200.]
#
# [['Apartad\xc3\xb3', 'Cocorn\xc3\xa1', 'Olaya', 'Tarso', 'Titirib\xc3\xad', 'Urrao', 'San Jacinto', 'Chiscas', 'Covarach\xc3\xada', 'Santa Sof\xc3\xada', 'San Jos\xc3\xa9', 'Aguachica', 'La Gloria', 'La Jagua de Ibirico', 'Pailitas', 'R\xc3\xado De Oro', 'San Diego', 'Susa', 'Yacop\xc3\xad', 'Plato', 'Salazar', 'Jes\xc3\xbas Mar\xc3\xada', 'V\xc3\xa9lez', 'Buenavista'], ['Abejorral', 'Amag\xc3\xa1', 'Amalfi', 'Angel\xc3\xb3polis', 'Angostura', 'Anori', 'Anza', 'Belmira', 'Betania', 'Betulia', 'Ciudad Bol\xc3\xadvar', 'Brice\xc3\xb1o', 'Buritica', 'C\xc3\xa1ceres', 'Caicedo', 'Campamento*', 'Carepa', 'Concordia', 'Dabeiba', 'Frontino', 'Granada', 'Ituango', 'Liborina', 'Montebello', 'Murindo', 'Mutat\xc3\xa1', 'Nari\xc3\xb1o', 'Necocl\xc3\xad', 'Nech\xc3\xad', 'Peque', 'Puerto Triunfo', 'Remedios', 'Sabanalarga', 'Salgar', 'San Francisco', 'San Juan de Uraba', 'San Luis', 'Segovia', 'Sons\xc3\xb3n', 'Taraza', 'Turbo', 'Uramita', 'Valdivia', 'Vegach\xc3\xad', 'Vig\xc3\xada del  Fuerte', 'Yal\xc3\xad', 'Yolomb\xc3\xb3', 'Yondo', 'Zaragoza', 'Sabanagrande', 'Arenal', 'Barranco De Loba', 'Cantagallo', 'Morales', 'Rio Viejo', 'San Pablo', 'Santa Rosa del Norte', 'Santa Rosa Del Sur', 'Simit\xc3\xad', 'Soplaviento', 'Tiquisio', 'Brice\xc3\xb1o', 'Buenavista', 'Campohermoso', 'Chitaraque', 'Ci\xc3\xa9nega', 'Coper', 'Cubara', 'Cucaita', 'Ch\xc3\xadquiza', 'Guican', 'Jeric\xc3\xb3', 'Labranzagrande', 'Maripi', 'Motavita', 'Otan
*', 'San Juan De Arama', 'San Juanito', 'San Mart\xc3\xadn', 'Vista Hermosa', 'Aldana', 'Barbacoas', 'Buesaco', 'Contadero', 'C\xc3\xb3rdoba', 'Cuaspud Carlosama', 'Cumbal', 'Cumbitara*', 'Chachagui', 'El Charco', 'El Pe\xc3\xb1ol', 'El Rosario', 'El Tabl\xc3\xb3n', 'El Tambo', 'Funes', 'Guait ...
# Se encontraron los Clusters solicitados: 5
# Los centros pedidos son:
# [array([-0.27794227, -0.75333132, -0.05759189]), array([-0.24438047, -0.46195963, -0.12177531]), array([-0.62311303, -0.55704738, -0.07796908]), array([-0.50308589, -0.27310466, -0.13028259]), array([-1.01764108, -0.22997114, -0.16702622])]
#
# ÉL numero de puntos por Cluster es:
# [ 163.  459.   32.   43.  416.]
#
# [['Apartad\xc3\xb3', 'Arboletes', 'Armenia', 'Caucasia', 'Cocorn\xc3\xa1', 'San Pedro de Urab\xc3\xa1', 'Titirib\xc3\xad', 'Urrao', 'Candelaria', 'Galapa', 'Luruaco', 'Manat\xc3\xad', 'Polonuevo', 'Repel\xc3\xb3n', 'Santa Luc\xc3\xada', 'Su\xc3\xa1n', 'Ach\xc3\xad', 'Altos Del Rosario', 'Arjona', 'Arroyohondo', 'Calamar', 'Cicuco', 'C\xc3\xb3rdoba', 'Clemencia', 'El Carmen de Bolivar', 'El Guamo', 'El Pe\xc3\xb1on', 'Magangu\xc3\xa9', 'Mahates', 'Mar\xc3\xada la Baja', 'Montecristo', 'Mompox', 'Pinillos', 'Regidor', 'San Cristobal', 'San Estanislao', 'San Fernando', 'San Jacinto Del Cauca', 'San Juan Nepomuceno', 'Santa Catalina', 'Talaigua Nuevo', 'Turban\xc3\xa1', 'Villanueva', 'Zambrano', 'Bet\xc3\xa9itiva', 'Boyac\xc3\xa1', 'Chita', 'Chivat\xc3\xa1', 'Covarach\xc3\xada', 'Cuitiva', 'Jenesano', 'La Victoria', 'R\xc3\xa1quira', 'Rond\xc3\xb3n', 'Saboya', 'San Jos\xc3\xa9 De Pare', 'Santana', 'Santa Sof\xc3\xada', 'Siachoque', 'Tiban\xc3\xa1', 'Tipacoque', 'Tutaz\xc3\xa1', 'San Jos\xc3\xa9', 'L\xc3\xb3pez de Micay', 'Agust\xc3\xadn Codazzi', 'Astrea', 'Curumani', 'Gamarra', 'La Gloria', 'Pailitas', 'Pelaya', 'R\xc3\xado De Oro', 'Tamalameque', 'Ayapel', 'Buenavista', 'Canalete', 'Chima', 'Ci\xc3\xa9naga De Oro', 'Cotorra', 'La Apartada', 'Lorica', 'Los C\xc3\xb3rdobas', 'Momil', 'Mo\xc3\xb1itos', 'Planeta Rica', 'Pueblo Nuevo', 'Puerto Escondido', 'Pur\xc3\xadsima', 'Sahag\xc3\xban', 'San Antero', 'San Bernardo Del Viento', 'San Carlos', 'San Pelayo', 'La Pe\xc3\xb1a', 'Topaip\xc3\xad', 'Yacop\xc3\xad', 'Bah\xc3\xada Solano', 'El Carmen de Atrato', 'Aipe', 'Riohacha', 'Barrancas', 'El Molino', 'San Juan del Cesar', 'Villanueva', 'Cerro San Antonio', 'Concordia', 'El Pi\xc3\xb1on', 'El Ret\xc3\xa9n', 'Guamal', 'Pedraza', 'Piji\xc3\xb1o Del Carmen', 'Plato', 'Remolino', 'Salamina', 'San Sebasti\xc3\xa1n De Buenavista', 'San Zen\xc3\xb3n', 'Santa Ana', 'Santa B\xc3\xa1rbara De Pinto', 'Sitionuevo', 'Tenerife', 'Zapay\xc3\xa1n', 'Zona Bananera', 'Alban', 'Arboleda', 'Colon', 'Guachucal', 'La Cruz', 'Cucutilla', 'El Carmen', 'Salazar', 'Chipata', 'Macaravita', 'San Benito', 'Caimito', 'Coloso', 'Chalan', 'El Roble', 'Guaranda', 'La Uni\xc3\xb3n', 'Los Palmitos', 'Majagual', 'Morroa', 'Ovejas', 'Palmito', 'Sampues', 'San Benito Abad', 'San Marcos', 'San Onofre', 'San Pedro', 'Sinc\xc3\xa9', 'Sucre', 'Coello', 'Coyaima', 'Dolores', 'Natagaima', 'San Lu\xc3\xads', 'Su\xc3\xa1rez', 'Valle de San Juan', 'Venadillo', 'Arauquita', 'El Retorno*', 'Mit\xc3\xba', 'Caruru*'], ['Medell\xc3\xadn', 'Abriaqui', 'Santaf\xc3\xa9 de Antioquia', 'Barbosa', 'Bello', 'Caldas', 'Caracol\xc3\xad', 'Caramanta', 'El Carmen De Viboral', 'Carolina del Principe', 'Chigorod\xc3\xb3', 'Cisneros', 'Copacabana', 'Ebejic\xc3\xb3', 'Envigado', 'Fredonia', 'Giraldo', 'Girardota', 'G\xc3\xb3mez Plata', 'Guarne', 'Guatape', 'Heliconia', 'Hispania', 'Itagui', 'Jeric\xc3\xb3', 'La Ceja', 'La Estrella', 'La Pintada', 'Maceo', 'Marinilla', 'Olaya', 'Pe\xc3\xb1ol', 'Pueblorrico', 'Puerto Nare (La Magdalena)', 'Retiro', 'Rionegro', 'Sabaneta', 'San Andr\xc3\xa9s de Cuerquia', 'San Carlos', 'San Jer\xc3\xb3nimo', 'San Jos\xc3\xa9 de la Monta\xc3\xb1a', 'San Pedro de los Milagros', 'San Rafael', 'Santa B\xc3\xa1rbara', 'Santo Domingo', 'Sopetr\xc3\xa1n', 'T\xc3\xa1mesis', 'Tarso', 'Valpara\xc3\xadso', 'Venecia', 'Yarumal', 'Barranquilla', 'Baranoa', 'Juan de Acosta', 'Malambo', 'Palmar de Varela', 'Piojo', 'Puerto Colombia', 'Sabanalarga', 'Santo Tom\xc3\xa1s', 'Tubar\xc3\xa1', 'Usiacuri', 'Bogot\xc3\xa1 D.C.', 'Cartagena', 'San Jacinto', 'Turbaco', 'Tunja', 'Almeida', 'Aquitania', 'Arcabuco', 'Bel\xc3\xa9n', 'Berbeo', 'Boavita', 'Busbanz\xc3\xa1', 'Caldas', 'Cerinza', 'Chinavita', 'Chiquinquir\xc3\xa1', 'Chiscas', 'C\xc3\xb3mbita', 'Corrales', 'Chivor', 'Duitama', 'El Cocuy', 'El Espino', 'Firavitoba', 'Floresta', 'Gachantiv\xc3\xa1', 'G\xc3\xa1meza', 'Garagoa', 'Guacamayas', 'Guateque', 'Guayat\xc3\xa1', 'Iza', 'La Capilla', 'La Uvita', 'Villa De Leyva', 'Macanal', 'Mirafl ...
